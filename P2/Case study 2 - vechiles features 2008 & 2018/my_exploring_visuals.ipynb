# %% [markdown]
# # Exploring with Visuals
# Use `clean_08.csv` and `clean_18.csv`. You should've created these data files in the previous section: *Fixing Data Types Pt 3*.

# %%
# load datasets
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline

df_08 = pd.read_csv('clean_08.csv')
df_18 = pd.read_csv('clean_18.csv')

# %%
df_08.hist(figsize=(7,7))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbfff1d5940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffd13ba20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffd0f5a20>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbffd0aea20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffd065a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffd065a58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbffd051470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffd00b470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffcfc19b0>]], dtype=object)

# %%
df_18.hist(figsize=(7,7))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f35de286da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35de0fd0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35de0b5160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f35de0ccb00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35de02a0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35de02a128>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f35de009be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35ddfce0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35ddf87630>]], dtype=object)

# %%
pd.plotting.scatter_matrix(df_08, figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbffcf55668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffcd61e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffcd81748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffcd53d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffcd2dba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffcd2d6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffccdeb70>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbffcc99b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffcc5b0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffcc06630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffcbc0630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffcb79630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffcb33b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffcb3b898>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbffcaa20f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffcaccfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffca87470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffca44f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc9f7b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc9afb70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc973080>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc923f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc9c8390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc911630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc8ccb00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc88f080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc82beb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc7f20f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc7a9470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc7cb6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc721400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc74cb70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc702b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc6bbfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc67f550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc75c0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc5e6630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc61d630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc5d7a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc590a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc545160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc5001d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc4b9160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc474160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc49be10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc454e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc410da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc3c7da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbffc3b1400>]], dtype=object)

# %%
df_08['cmb_mpg'].plot(kind= 'hist')

# %%
df_18['cmb_mpg'].plot(kind= 'hist')

# %%
pd.plotting.scatter_matrix(df_08, figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f35dd0e9b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35dccf9048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35dcc9ff28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35dce52f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35dce0df98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35dce0dfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35dcd79ac8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f35dcd33f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35dc42f518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35dcd84a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35dc416a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35dc3d0ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35dc36f358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35dc342a58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f35ddb29fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35dc35be80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35dc308710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35dc2d9e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35dc300518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35dc2476a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35dc2016a0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f35dc1bc6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35dc173be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35dc129160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35dc163160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35dc11a160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35dc0d46a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35dc07ba90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f35dc03aa20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35d6fcda20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35d6f82f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35d6f90f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35d6f74550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35d6f2f550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35d6ee6a90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f35d6ea0a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35d6e45ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35d6e02e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35d6e3def0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35d6df8ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35d6e16c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35d6d649b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f35d6d1ce10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35d6cd9e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35d6c8ed30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35d6c45470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35d6c00940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35d6c3c940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35d6bf4940>]], dtype=object)
